# %%
price_range = [0, 50, 100, 200, 500, 1000, 5000, 50000]

# %%
for s, i in enumerate(price_range):
    print("{}\n{}".format(s,i))
# Out:
# 0
# 0
# 1
# 50
# 2
# 100
# 3
# 200
# 4
# 500
# 5
# 1000
# 6
# 5000
# 7
# 50000
